# %%
# !pip install gTTS

# %%
from gtts import gTTS # Corrected the capitalization of gTTS
from IPython.display import Audio

# %%
text = input("Enter the sentence which should be converted to speech")

# %%
tts=gTTS(text=text,lang='en')
tts.save('output.mp3')

# %%
from re import A
Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
